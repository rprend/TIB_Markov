# %%
import os
from bs4 import BeautifulSoup

# %%
words_dict = {}

# %%
#96,579 total
umph = 0
ranges = [500 * x for x in range(1,193)]
for x in range(1,96579):
    umph += 1
    if umph in ranges:
        print(umph)
    with open("/home/rprendergast/Documents/School/TIB/index.html.%d"%x) as TIB:
        unparsed_essay = BeautifulSoup(TIB,"html5lib").get_text()
#         print(unparsed_essay)
        umph += 1
        if "Sponsor This Essay" in unparsed_essay:
            start_idx = unparsed_essay.index("Sponsor This Essay") + 19
        else:
            continue
        end_idx = unparsed_essay.index("\t\tDonate")
        parsed_essay = unparsed_essay[start_idx:end_idx]
        parsed_essay = parsed_essay.strip()
#         print(parsed_essay)
        parsed_essay_list = [a.strip() for a in parsed_essay.split(' ')]
        for idx,word in enumerate(parsed_essay_list):
            if (idx == len(parsed_essay_list) - 1):
                break
            if word not in words_dict:
                words_dict[word] = []
            words_dict[word].append(parsed_essay_list[idx+1])
# Out:
# 104
# 126
# 766
# 1420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-267cf2b3fb2e> in <module>()
#       4     umph += 1
#       5     with open("/home/rprendergast/Documents/School/TIB/index.html.%d"%x) as TIB:
# ----> 6         unparsed_essay = BeautifulSoup(TIB,"html5lib").get_text()
#       7 #         print(unparsed_essay)
#       8         umph += 1
#
# /usr/lib/python3/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     213             self.reset()
#     214             try:
# --> 215                 self._feed()
#     216                 break
#     217             except ParserRejectedMarkup:
#
# /usr/lib/python3/dist-packages/bs4/__init__.py in _feed(self)
#     237         self.builder.reset()
#     238
# --> 239         self.builder.feed(self.markup)
#     240         # Close out any unfinished strings and close all the open tags.
#     241         self.endData()
#
# /usr/lib/python3/dist-packages/bs4/builder/_html5lib.py in feed(self, markup)
#      48             warnings.warn("You provided a value for parse_only, but the html5lib tree builder doesn't support parse_only. The entire document will be parsed.")
#      49         parser = html5lib.HTMLParser(tree=self.create_treebuilder)
# ---> 50         doc = parser.parse(markup, encoding=self.user_specified_encoding)
#      51
#      52         # Set the character encoding detected by the tokenizer.
#
# /usr/lib/python3/dist-packages/html5lib/html5parser.py in parse(self, stream, encoding, parseMeta, useChardet)
#     222         """
#     223         self._parse(stream, innerHTML=False, encoding=encoding,
# --> 224                     parseMeta=parseMeta, useChardet=useChardet)
#     225         return self.tree.getDocument()
#     226
#
# /usr/lib/python3/dist-packages/html5lib/html5parser.py in _parse(self, stream, innerHTML, container, encoding, parseMeta, useChardet, **kwargs)
#      91         while True:
#      92             try:
# ---> 93                 self.mainLoop()
#      94                 break
#      95             except ReparseException:
#
# /usr/lib/python3/dist-packages/html5lib/html5parser.py in mainLoop(self)
#     185                         new_token = phase.processSpaceCharacters(new_token)
#     186                     elif type == StartTagToken:
# --> 187                         new_token = phase.processStartTag(new_token)
#     188                     elif type == EndTagToken:
#     189                         new_token = phase.processEndTag(new_token)
#
# /usr/lib/python3/dist-packages/html5lib/html5parser.py in processStartTag(self, token)
#     466
#     467         def processStartTag(self, token):
# --> 468             return self.startTagHandler[token["name"]](token)
#     469
#     470         def startTagHtml(self, token):
#
# /usr/lib/python3/dist-packages/html5lib/html5parser.py in startTagCloseP(self, token)
#    1031             if self.tree.elementInScope("p", variant="button"):
#    1032                 self.endTagP(impliedTagToken("p"))
# -> 1033             self.tree.insertElement(token)
#    1034
#    1035         def startTagPreListing(self, token):
#
# /usr/lib/python3/dist-packages/html5lib/treebuilders/_base.py in insertElementNormal(self, token)
#     289         namespace = token.get("namespace", self.defaultNamespace)
#     290         element = self.elementClass(name, namespace)
# --> 291         element.attributes = token["data"]
#     292         self.openElements[-1].appendChild(element)
#     293         self.openElements.append(element)
#
# /usr/lib/python3/dist-packages/bs4/builder/_html5lib.py in setAttributes(self, attributes)
#     205
#     206             converted_attributes = []
# --> 207             for name, value in list(attributes.items()):
#     208                 if isinstance(name, tuple):
#     209                     new_name = NamespacedAttribute(*name)
#
# KeyboardInterrupt:

# %%
print(words_dict)
# Out:
# {'': ['I', 'More', 'I', 'Latte', 'She', 'This', 'After', 'I', '', 'I', 'She', '', 'Apparently,', 'Before', 'I', 'Latte', 'I', 'I', 'She', 'I', 'That', '', 'My', 'Each', 'If', 'In', 'When', 'As', 'Yes', 'At', 'It', 'These', 'These', 'My', 'I', 'I', 'I', 'I', 'Mathematics', 'It', 'Science', 'Tom', 'in', 'The', 'The', 'Religion', 'This', 'But', 'I', 'We', 'It', 'My', 'I', 'I', 'I', 'I', 'While', 'I', 'I', 'The', 'It', 'I', 'It', 'believe', '', 'My', '', 'The', 'As', 'The', '', 'One:', 'He', '', '', '', 'For', 'no', '', 'Two:', 'Practice', '', 'Three:', '', '', '', 'What', 'To', '', 'Finally,', '', '”', '', '“Edgar,”', 'said,', '', '”', '', 'Five', '', '', '', 'Lucky', 'If', 'both', 'Also', 'For', 'I', 'I', '“you', '', 'I', 'A', 'We', 'I', 'Either', 'I', '“Music', 'A', 'We', 'The', 'The', 'Yes', 'It', 'We', 'Obviously', 'We', 'We', '', '', '', 'What', '', '', '', 'I', '', '', '', '', '', '', '', '', 'I', 'No', 'I', 'Sometimes', 'Life', 'Photo', 'I', 'Never', 'I’ve', 'As', 'The', 'We', 'We', 'We', 'Nothing', 'A', 'They', 'Too', 'We', 'We', 'It', 'The', 'Instead', 'It', 'Not', 'Must', 'Once', 'Such', 'For', 'I', 'Was', 'When', 'If', 'I', 'One', 'It', 'In', 'about', 'I', 'The', 'We', 'All', 'And', 'I', 'These', 'Whether', 'Millions', 'My', 'It', 'I', 'My', 'A', 'In', 'In', 'And', 'Could', 'The', 'As', 'sometimes', 'Now\nI', 'In', 'Among', 'in', 'might', 'Photo', 'It', 'Sweet', 'I', 'I', 'I,', 'The', 'Rows', 'Beds', 'A', 'There', 'There', 'We', 'Parents', 'Of', 'So', 'Inside', 'Then', 'I', 'Each', 'I', 'The', 'I', 'There', 'It', 'I', 'Now', 'I', 'I', 'I', 'It’s', 'He', 'Brubeck', 'I', 'I', 'The', 'Some', 'I', 'I', 'I', 'I', 'I', 'And', 'On', 'In', 'I', 'Embedded', 'My', 'In', 'I’m', 'I', 'I', 'Because', 'I', 'I', 'My', 'I', 'By', 'This', 'However,', 'What', 'Is', 'While', 'How', 'I', 'I', 'Some', 'They', 'It', 'The', 'If', 'No', 'Go', 'There', 'Timidity', 'It', 'Timidity', 'But', 'I', 'I', 'I', 'At', 'I’ve', 'But', 'That’s', 'My', 'Telling', 'Thanks', 'They', 'But', 'We', 'Retelling', 'We', 'Learn', 'Also', 'Your', 'I', 'More', 'I', 'Latte', 'She', 'This', 'After', 'I', '', 'I', 'She', '', 'Apparently,', 'Before', 'I', 'Latte', 'I', 'I', 'She', 'I', 'That', '', 'My', 'Each', 'If', 'In', 'When', 'As', 'Yes', 'At', 'It', 'These', 'These', 'My', 'I', 'I', 'I', 'I', 'Mathematics', 'It', 'Science', 'Tom', 'in', 'The', 'The', 'Religion', 'This', 'But', 'I', 'We', 'It', 'My', 'I', 'I', 'I', 'I', 'While', 'I', 'I', 'The', 'It', 'I', 'It', 'believe', '', 'My', '', 'The', 'As', 'The', '', 'One:', 'He', '', '', '', 'For', 'no', '', 'Two:', 'Practice', '', 'Three:', '', '', '', 'What', 'To', '', 'Finally,', '', '”', '', '“Edgar,”', 'said,', '', '”', '', 'Five', '', '', '', 'Lucky', 'If', 'both', 'Also', 'For', 'I', 'I', '“you', '', 'I', 'A', 'We', 'I', 'Either', 'I', '“Music', 'A', 'We', 'The', 'The', 'Yes', 'It', 'We', 'Obviously', 'We', 'We', '', '', '', 'What', '', '', '', 'I', '', '', '', '', '', '', '', '', 'I', 'No', 'I', 'Sometimes', 'Life', 'Photo', 'I', 'Never', 'I’ve', 'As', 'The', 'We', 'We', 'We', 'Nothing', 'A', 'They', 'Too', 'We', 'We', 'It', 'The', 'Instead', 'It', 'Not', 'Must', 'Once', 'Such', 'For', 'I', 'Was', 'When', 'If', 'I', 'One', 'It', 'In', 'about', 'I', 'The', 'We', 'All', 'And', 'I', 'These', 'Whether', 'Millions', 'My', 'It', 'I', 'My', 'A', 'In', 'In', 'And', 'Could', 'The', 'As', 'sometimes', 'Now\nI', 'In', 'Among', 'in', 'might', 'Photo', 'It', 'Sweet', 'I', 'I', 'I,', 'The', 'Rows', 'Beds', 'A', 'There', 'There', 'We', 'Parents', 'Of', 'So', 'Inside', 'Then', 'I', 'Each', 'I', 'The', 'I', 'There', 'It', 'I', 'Now', 'I', 'I', 'I', 'It’s', 'He', 'Brubeck', 'I', 'I', 'The', 'Some', 'I', 'I', 'I', 'I', 'I', 'And', 'On', 'In', 'I', 'Embedded', 'My', 'In', 'I’m', 'I', 'I', 'Because', 'I', 'I', 'My', 'I', 'By', 'This', 'However,', 'What', 'Is', 'While', 'How', 'I', 'I', 'Some', 'They', 'It', 'The', 'If', 'No', 'Go', 'There', 'Timidity', 'It', 'Timidity', 'But', 'I', 'I', 'I', 'At', 'I’ve', 'But', 'That’s', 'My', 'Telli ...

# %%
print(len(words_dict))
# Out:
# 5877

# %%
print(umph)
# Out:
# 104
